# %%
# !cat python-workshop-369005-da7a8c3e4340.json
# Out:
# {
#   "type": "service_account",
#   "project_id": "python-workshop-369005",
#   "private_key_id": "da7a8c3e4340cbcbf828b3ac0830a0a6a8ce35de",
# ...

# %%
credential_file = "/Users/husnusensoy/Documents/code/python-training-2910/week4/python-workshop-369005-da7a8c3e4340.json"

# %%
import os

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_file

# %%
project_id = "python-workshop-369005"

# %%
import pandas as pd

# %%
pd.read_gbq("select * from `nyc-tlc.green.trips_2014`limit 10"
, project_id=project_id
, dialect="standard"
, use_bqstorage_api=True)
# Out:
#             pickup_datetime          dropoff_datetime store_and_fwd_flag  \
# 0 2014-03-02 04:45:22+00:00 2014-03-02 04:56:02+00:00                  N
# 1 2014-03-02 16:46:55+00:00 2014-03-02 16:59:17+00:00                  Y
# 2 2014-03-25 10:07:58+00:00 2014-03-25 10:14:55+00:00                  N
# 3 2014-01-06 08:31:05+00:00 2014-01-06 08:42:59+00:00                  N
# 4 2014-03-26 18:40:12+00:00 2014-03-26 18:41:04+00:00                  N
# 5 2014-04-03 23:35:00+00:00 2014-04-03 23:40:38+00:00                  N
# 6 2014-02-10 09:01:59+00:00 2014-02-10 09:19:09+00:00                  N
# 7 2014-02-11 04:46:12+00:00 2014-02-11 05:04:45+00:00                  N
# 8 2014-02-11 10:55:42+00:00 2014-02-11 11:01:59+00:00                  N
# 9 2014-03-12 07:58:54+00:00 2014-03-12 08:17:40+00:00                  N
#
#    rate_code  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          5        -73.958099        40.815525         -73.922707
# ...

# %%
# !pip install pandas-gbq
# Out:
# ...
#   Using cached pyarrow-9.0.0-cp38-cp38-macosx_10_13_x86_64.whl (24.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 1.1 MB/s eta 0:00:000:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 2.1 MB/s eta 0:00:006.2 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 4.1 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.9/211.9 kB 2.5 MB/s eta 0:00:004.9 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 2.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.8/483.8 kB 3.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 2.9 MB/s eta 0:00:00m eta 0:00:01
# ...
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 2.2 MB/s eta 0:00:00
# ...
