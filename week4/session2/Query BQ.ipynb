# %%
import os

import pandas as pd

# %%
CREDENTIAL_FILE="/Users/husnusensoy/Documents/code/python-training-2910/week4/session2/python-workshop-369005-a89d082a12b6.json"

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = CREDENTIAL_FILE

# %%
PROJECT_ID = "python-workshop-369005"

# %%
df = pd.read_gbq("select * from `nyc-tlc.green.trips_2014` limit 100"
, project_id=PROJECT_ID
,dialect="standard"
,use_bqstorage_api=True)

# %%
def run_bq(sql:str):
    return pd.read_gbq(sql
    , project_id=PROJECT_ID
    ,dialect="standard"
    ,use_bqstorage_api=True)

# %%
run_bq("select * from `nyc-tlc.green.trips_2014` limit 100")
# Out:
#              pickup_datetime          dropoff_datetime store_and_fwd_flag  \
# 0  2014-04-01 07:30:48+00:00 2014-04-01 07:41:32+00:00                  N
# 1  2014-01-04 06:42:57+00:00 2014-01-04 06:56:20+00:00                  N
# 2  2014-04-02 11:01:22+00:00 2014-04-02 11:14:41+00:00                  N
# 3  2014-03-07 12:22:56+00:00 2014-03-07 13:09:48+00:00                  N
# 4  2014-03-08 10:14:52+00:00 2014-03-08 10:35:29+00:00                  N
# ..                       ...                       ...                ...
# 95 2014-04-10 09:50:48+00:00 2014-04-10 09:54:41+00:00                  N
# 96 2014-07-29 23:24:06+00:00 2014-07-29 23:34:49+00:00                  N
# 97 2014-07-30 08:05:46+00:00 2014-07-30 08:16:45+00:00                  N
# 98 2014-10-10 18:45:37+00:00 2014-10-10 18:45:37+00:00                  Y
# 99 2014-08-08 19:57:17+00:00 2014-08-08 19:57:55+00:00                  N
#
#     rate_code  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
credentials = os.environ['GOOGLE_APPLICATION_CREDENTIALS']

print(credentials)
# Out:
# /Users/husnusensoy/Documents/code/python-training-2910/week4/session2/python-workshop-369005-a89d082a12b6.json

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/Users/husnusensoy/Documents/code/python-training-2910/week4/session2/python-workshop-369005-a89d082a12b6.json'

# %%
run_bq("select 1")
# Out:
#    f0_
# 0    1
